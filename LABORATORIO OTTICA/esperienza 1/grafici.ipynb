# %%
import matplotlib.pyplot as plt
import numpy as np

i = np.array([37.3,40.3,44.5,51.5,54.0,57.0,60.0,63.3,69.0,74.5])
delta = np.array([55.0,50.0,46.5,45.0,44.5,46.0,47.0,47.0,50.0,53.0])

plt.grid()
plt.scatter(i,delta)
